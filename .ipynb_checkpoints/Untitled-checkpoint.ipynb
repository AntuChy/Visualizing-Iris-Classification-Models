# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


var=[1,2,3,4,5,6,7]
var_1=[2,3,4,2,5,6,7]

x_1=pd.DataFrame({"var":var,"var_1":var_1})

sns.lineplot(x="var",y="var_1",data=x_1)
plt.show()

# %%
plt.plot(var,var_1)
plt.show()

# %%
y_1=sns.load_dataset("iris.data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 y_1=sns.load_dataset("iris.data")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:582, in load_dataset(name, cache, data_home, **kws)
#     580 if not os.path.exists(cache_path):
#     581     if name not in get_dataset_names():
# --> 582         raise ValueError(f"'{name}' is not one of the example datasets.")
#     583     urlretrieve(url, cache_path)
#     584 full_path = cache_path
#
# ValueError: 'iris.data' is not one of the example datasets.

# %%
sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=y_1,hue="sex")
plt.grid()
plt.title("python")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=y_1,hue="sex")
#       2 plt.grid()
#       3 plt.title("python")
#
# NameError: name 'y_1' is not defined

# %%
sns.displot(y_1["flipper_length_mm"],kde=True)
plt.show()

# %%
sns.barplot(x="island",y="bill_length_mm",data=y_1,hue="sex")
plt.show()

# %%
sns.scatterplot(x="bill_depth_mm",y="bill_length_mm",data=y_1,hue="sex")
plt.show()

# %%
x= y_1.drop(columns=["species","island","sex"],axis=1).head(10)
x
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0            39.1           18.7              181.0       3750.0
# 1            39.5           17.4              186.0       3800.0
# 2            40.3           18.0              195.0       3250.0
# 3             NaN            NaN                NaN          NaN
# 4            36.7           19.3              193.0       3450.0
# 5            39.3           20.6              190.0       3650.0
# 6            38.9           17.8              181.0       3625.0
# 7            39.2           19.6              195.0       4675.0
# 8            34.1           18.1              193.0       3475.0
# 9            42.0           20.2              190.0       4250.0

# %%
sns.heatmap(x,annot=True)
plt.show()

# %%
# Out:
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\lib\site-packages (0.24.2)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn) (1.20.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn) (1.7.1)
